# %%
# Imports
import pandas as pd
import numpy as np
from statistics import stdev, mean
import matplotlib.pyplot as plt
import yfinance as yf

# %%
"""
Instructions: 
use yfinance to query ytd stock prices for four stocks of your choosing. We´ve got 181 days worth of data this year. 
Get the first 181 days of data for the same stocks in 2022
Make sure the ticket symbol is a feature. This may require you to address multiindexed columns
Create a feature called Range and assign to it the difference between high and low
Imagine we want to produce a line chart with one of the tickers, 
plotting 2022 data against 2023 data, with the temporal measure on the x-axis. 
think of and implement a way to accomplish this. 
Consider adding a feature that represents the dates in a different yet consistent way
if you have time, attempt a basic matplotlib pyplot as described above
"""
# Out:
# '\nInstructions: \nuse yfinance to query ytd stock prices for four stocks of your choosing. We´ve got 181 days worth of data this year. \nGet the first 181 days of data for the same stocks in 2022\nMake sure the ticket symbol is a feature. This may require you to address multiindexed columns\nCreate a feature called Range and assign to it the difference between high and low\nImagine we want to produce a line chart with one of the tickers, \nplotting 2022 data against 2023 data, with the temporal measure on the x-axis. \nthink of and implement a way to accomplish this. \nConsider adding a feature that represents the dates in a different yet consistent way\nif you have time, attempt a basic matplotlib pyplot as described above\n'

# %%
# Selection of stocks
stocks = ["AAPL", "GOOG", "INTC", "SPYD", "QQQ"]
# Ticker objects
tickers = yf.Tickers(stocks)

# %%
history_previous_year = tickers.history(start="2022-01-01", end="2022-09-21")
history_previous_year
# Out:
# [*********************100%%**********************]  5 of 5 completed
#            Capital Gains            Close                                     \
#                      QQQ SPYD        AAPL        GOOG       INTC         QQQ
# Date
# 2022-01-03           0.0  0.0  180.190964  145.074493  50.175880  397.004974
# 2022-01-04           0.0  0.0  177.904053  144.416504  50.109867  391.855652
# 2022-01-05           0.0  0.0  173.171829  137.653503  50.798244  379.817413
# 2022-01-06           0.0  0.0  170.281006  137.550995  50.930256  379.550507
# 2022-01-07           0.0  0.0  170.449341  137.004501  50.392761  375.438965
# ...                  ...  ...         ...         ...        ...         ...
# 2022-09-14           0.0  0.0  154.394058  105.870003  28.226994  293.509460
# 2022-09-15           0.0  0.0  151.471405  103.900002  27.898100  288.621429
# 2022-09-16           0.0  0.0  149.811249  103.629997  28.285034  286.856598
# ...

# %%
history_previous_year.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 180 entries, 2022-01-03 to 2022-09-20
# Data columns (total 37 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (Capital Gains, QQQ)   180 non-null    float64
#  1   (Capital Gains, SPYD)  180 non-null    float64
#  2   (Close, AAPL)          180 non-null    float64
#  3   (Close, GOOG)          180 non-null    float64
#  4   (Close, INTC)          180 non-null    float64
#  5   (Close, QQQ)           180 non-null    float64
#  6   (Close, SPYD)          180 non-null    float64
#  7   (Dividends, AAPL)      180 non-null    float64
#  8   (Dividends, GOOG)      180 non-null    float64
#  9   (Dividends, INTC)      180 non-null    float64
#  10  (Dividends, QQQ)       180 non-null    float64
#  11  (Dividends, SPYD)      180 non-null    float64
#  12  (High, AAPL)           180 non-null    float64
#  13  (High, GOOG)           180 non-null    float64
# ...
